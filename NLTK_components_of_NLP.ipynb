# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanveer132/NLP_Practices_End_to_End/blob/main/NLTK_components_of_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Natural Language Processing -
#
# ## What is Natural Language Processing
#
#     In natural language processing, human language is separated into fragments so that the grammatical structure of sentences
#     and the meaning of words can be analyzed and understood in context. This helps computers read and understand spoken
#     or written text in the same way as humans.
#
# ## What are the applications of NLP
#
#     1. Autocorrect and Autocomplete
#     2. Language Translator
#     3. Chatbots
#     4. Targeted Advertising i.e. show advertise as per search accured.
#     5. Hiring and Recruitment
#     6. Voice Assistant  e.g. apple's siri, google's assisatnt, microsoft's cortana
#     7. Grammer Checkers
#     8. Email filtering
#     9. sentimental Analysis
#
# ## What are the process of NLP
#
# 1. Natural Language Understanding
#
#     1. Mapping input to useful representation
#     2. Analysing Different aspects of the language
#
# 2. Natural Language Generation
#
#     1. text planning
#     2. sentence planning
#     3. text realization
#
# ## NLP Components
#
# 1. Tokenization :
# 2. Stemming
# 3. Lemmatization
# 4. Stop Words
# 5. parts of speech
# 6. NER - Named Entity Recognition
# 7. Syntax Tree
# 8. Chunking

# %% [markdown]
# Install NLTK and import library

# %%
# !pip install nltk

# %%
import os
import nltk
nltk.download('all')    #must download data from nltk to avoid error 
import nltk.corpus
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# ...

# %% [markdown]
# ## Tokenization :
#
# 1. Breaking up complex sentence into words.
# 2. Understand importance of each of the words in sentence.
# 3. Produce structural discription on input sentence.

# %%
nltk.download('corpora')
print(os.listdir(nltk.data.find("corpora")))
# Out:
# [nltk_data] Error loading corpora: Package 'corpora' not found in
# [nltk_data]     index
# ...

# %%
from nltk.corpus import brown
brown.words()
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
shakespeare = nltk.corpus.gutenberg.words('shakespeare-caesar.txt')
shakespeare
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Julius', 'Caesar', ...]

# %%
for words in shakespeare[:500]:
  print(words, sep=" ",end=" ")
# Out:
# [ The Tragedie of Julius Caesar by William Shakespeare 1599 ] Actus Primus . Scoena Prima . Enter Flauius , Murellus , and certaine Commoners ouer the Stage . Flauius . Hence : home you idle Creatures , get you home : Is this a Holiday ? What , know you not ( Being Mechanicall ) you ought not walke Vpon a labouring day , without the signe Of your Profession ? Speake , what Trade art thou ? Car . Why Sir , a Carpenter Mur . Where is thy Leather Apron , and thy Rule ? What dost thou with thy best Apparrell on ? You sir , what Trade are you ? Cobl . Truely Sir , in respect of a fine Workman , I am but as you would say , a Cobler Mur . But what Trade art thou ? Answer me directly Cob . A Trade Sir , that I hope I may vse , with a safe Conscience , which is indeed Sir , a Mender of bad soules Fla . What Trade thou knaue ? Thou naughty knaue , what Trade ? Cobl . Nay I beseech you Sir , be not out with me : yet if you be out Sir , I can mend you Mur . What mean ' st thou by that ? Mend mee
# ...

# %%
# User deifined text

AI = '''NLTK is a leading platform for building Python programs to work with human language data. It provides easy-to-use interfaces to over 50 corpora and lexical resources such as WordNet, along with a suite of text processing libraries for classification,
 tokenization, stemming, tagging, parsing, and semantic reasoning, wrappers for industrial-strength NLP libraries, and an active discussion forum.Thanks to a hands-on guide introducing programming fundamentals alongside topics in computational linguistics, 
plus comprehensive API documentation, NLTK is suitable for linguists, engineers, students, educators, researchers, and industry users alike. NLTK is available for Windows, Mac OS X, and Linux. Best of all, NLTK is a free, open source, community-driven project.'''

# %%
#It seperates the words, symbols in the string 

from nltk.tokenize import word_tokenize,sent_tokenize

AI_tokenize = word_tokenize(AI)
print(AI_tokenize[:10])
print(len(AI_tokenize))

sentence_tokenize = sent_tokenize(AI)
print(sentence_tokenize[:10])
print(len(sentence_tokenize))
# Out:
# ['NLTK', 'is', 'a', 'leading', 'platform', 'for', 'building', 'Python', 'programs', 'to']
# 130
# ['NLTK is a leading platform for building Python programs to work with human language data.', 'It provides easy-to-use interfaces to over 50 corpora and lexical resources such as WordNet, along with a suite of text processing libraries for classification,\n tokenization, stemming, tagging, parsing, and semantic reasoning, wrappers for industrial-strength NLP libraries, and an active discussion forum.Thanks to a hands-on guide introducing programming fundamentals alongside topics in computational linguistics, \nplus comprehensive API documentation, NLTK is suitable for linguists, engineers, students, educators, researchers, and industry users alike.', 'NLTK is available for Windows, Mac OS X, and Linux.', 'Best of all, NLTK is a free, open source, community-driven project.']
# 4

# %%
# to count the frequency of each word
from nltk.probability import FreqDist
fdist =  FreqDist()
for words in AI_tokenize:
  fdist[words.lower()]+=1

fdist
# Out:
# FreqDist({',': 20,
#           '.': 4,
#           '50': 1,
#           'a': 4,
#           'active': 1,
#           'alike': 1,
#           'all': 1,
#           'along': 1,
#           'alongside': 1,
#           'an': 1,
#           'and': 5,
#           'api': 1,
#           'as': 1,
#           'available': 1,
#           'best': 1,
#           'building': 1,
#           'classification': 1,
#           'community-driven': 1,
#           'comprehensive': 1,
#           'computational': 1,
#           'corpora': 1,
#           'data': 1,
#           'discussion': 1,
#           'documentation': 1,
#           'easy-to-use': 1,
#           'educators': 1,
#           'engineers': 1,
#           'for': 5,
#           'forum.thanks': 1,
#           'free': 1,
#           'fundamentals': 1,
#           'guide': 1,
#           'hands-on': 1,
#           'human': 1,
#           'in': 1,
#           'industrial-strength': 1,
#           'industry': 1,
#           'interfaces': 1,
# ...

# %%
fdist['tokenization']
# Out:
# 1

# %%
#To set most common words appeared

fdist_top10 = fdist.most_common(10)
fdist_top10
# Out:
# [(',', 20),
#  ('for', 5),
#  ('and', 5),
#  ('nltk', 4),
#  ('is', 4),
#  ('a', 4),
#  ('.', 4),
#  ('to', 3),
#  ('with', 2),
#  ('of', 2)]

# %% [markdown]
# ### Lower case words :
#
# We want our model to not get confused by seeing the same word with different cases like one starting with capital and one without and interpret both differently. So we convert all words into the lower case to avoid redundancy in the token list.

# %%
# Lower case words
import re

text = re.sub(r"[^a-zA-Z0-9]", " ", AI.lower())
words = text.split()
print(words)
# Out:
# ['nltk', 'is', 'a', 'leading', 'platform', 'for', 'building', 'python', 'programs', 'to', 'work', 'with', 'human', 'language', 'data', 'it', 'provides', 'easy', 'to', 'use', 'interfaces', 'to', 'over', '50', 'corpora', 'and', 'lexical', 'resources', 'such', 'as', 'wordnet', 'along', 'with', 'a', 'suite', 'of', 'text', 'processing', 'libraries', 'for', 'classification', 'tokenization', 'stemming', 'tagging', 'parsing', 'and', 'semantic', 'reasoning', 'wrappers', 'for', 'industrial', 'strength', 'nlp', 'libraries', 'and', 'an', 'active', 'discussion', 'forum', 'thanks', 'to', 'a', 'hands', 'on', 'guide', 'introducing', 'programming', 'fundamentals', 'alongside', 'topics', 'in', 'computational', 'linguistics', 'plus', 'comprehensive', 'api', 'documentation', 'nltk', 'is', 'suitable', 'for', 'linguists', 'engineers', 'students', 'educators', 'researchers', 'and', 'industry', 'users', 'alike', 'nltk', 'is', 'available', 'for', 'windows', 'mac', 'os', 'x', 'and', 'linux', 'best', 'of', 'al
# ...

# %%
#Number of paragraphs

from nltk.tokenize import blankline_tokenize

AI_blank = blankline_tokenize(AI)
print(AI_blank[:10])
print(len(AI_blank))
# Out:
# ['NLTK is a leading platform for building Python programs to work with human language data. It provides easy-to-use interfaces to over 50 corpora and lexical resources such as WordNet, along with a suite of text processing libraries for classification,\n tokenization, stemming, tagging, parsing, and semantic reasoning, wrappers for industrial-strength NLP libraries, and an active discussion forum.Thanks to a hands-on guide introducing programming fundamentals alongside topics in computational linguistics, \nplus comprehensive API documentation, NLTK is suitable for linguists, engineers, students, educators, researchers, and industry users alike. NLTK is available for Windows, Mac OS X, and Linux. Best of all, NLTK is a free, open source, community-driven project.']
# 1

# %%
# Bigrams, Trigrams and Ngrams 

from nltk.util import bigrams,trigrams,ngrams

sentence = "My village is wonderland for me and the hills around are way to sky."

# %%
quote_sentence = word_tokenize(sentence)
quote_sentence[:10]
# Out:
# ['My',
#  'village',
#  'is',
#  'wonderland',
#  'for',
#  'me',
#  'and',
#  'the',
#  'hills',
#  'around']

# %%
bigrams_quotes = list(bigrams(quote_sentence))
bigrams_quotes
# Out:
# [('My', 'village'),
#  ('village', 'is'),
#  ('is', 'wonderland'),
#  ('wonderland', 'for'),
#  ('for', 'me'),
#  ('me', 'and'),
#  ('and', 'the'),
#  ('the', 'hills'),
#  ('hills', 'around'),
#  ('around', 'are'),
#  ('are', 'way'),
#  ('way', 'to'),
#  ('to', 'sky'),
#  ('sky', '.')]

# %%
trigrams_quotes = list(trigrams(quote_sentence))
trigrams_quotes
# Out:
# [('My', 'village', 'is'),
#  ('village', 'is', 'wonderland'),
#  ('is', 'wonderland', 'for'),
#  ('wonderland', 'for', 'me'),
#  ('for', 'me', 'and'),
#  ('me', 'and', 'the'),
#  ('and', 'the', 'hills'),
#  ('the', 'hills', 'around'),
#  ('hills', 'around', 'are'),
#  ('around', 'are', 'way'),
#  ('are', 'way', 'to'),
#  ('way', 'to', 'sky'),
#  ('to', 'sky', '.')]

# %%
ngrams_quotes = list(ngrams(quote_sentence,6))
ngrams_quotes
# Out:
# [('My', 'village', 'is', 'wonderland', 'for', 'me'),
#  ('village', 'is', 'wonderland', 'for', 'me', 'and'),
#  ('is', 'wonderland', 'for', 'me', 'and', 'the'),
#  ('wonderland', 'for', 'me', 'and', 'the', 'hills'),
#  ('for', 'me', 'and', 'the', 'hills', 'around'),
#  ('me', 'and', 'the', 'hills', 'around', 'are'),
#  ('and', 'the', 'hills', 'around', 'are', 'way'),
#  ('the', 'hills', 'around', 'are', 'way', 'to'),
#  ('hills', 'around', 'are', 'way', 'to', 'sky'),
#  ('around', 'are', 'way', 'to', 'sky', '.')]

# %% [markdown]
# ## Stemming
#
# It normalizes words into its base roots form.
# In our text we may find many words like playing, played, playfully, etc… which have a root word, play all of these convey the same meaning. So we can just extract the root word and remove the rest. Here the root word formed is called ‘stem’ and it is not necessarily that stem needs to exist and have a meaning. Just by committing the suffix and prefix, we generate the stems.
#
# persuade - persuation - persuasive - persuaded - persuades

# %%
forms = ['persuade','persuation','persuasive','persuaded','persuades']

# %%
from nltk.stem import PorterStemmer
pst = PorterStemmer()

for words in forms:
  print(words +"->"+ pst.stem(words))
# Out:
# persuade->persuad
# persuation->persuat
# persuasive->persuas
# persuaded->persuad
# persuades->persuad

# %%
from nltk.stem import LancasterStemmer
pst = LancasterStemmer()

for words in forms:
  print(words +"->"+ pst.stem(words))
# Out:
# persuade->persuad
# persuation->persu
# persuasive->persuas
# persuaded->persuad
# persuades->persuad

# %%
from nltk.stem import SnowballStemmer
pst = SnowballStemmer('english')

for words in forms:
  print(words +"->"+ pst.stem(words))
# Out:
# persuade->persuad
# persuation->persuat
# persuasive->persuas
# persuaded->persuad
# persuades->persuad

# %% [markdown]
# ## Limmatization
#
# We want to extract the base form of the word here. The word extracted here is called Lemma and it is available in the dictionary. We have the WordNet corpus and the lemma generated will be available in this corpus. NLTK provides us with the WordNet Lemmatizer that makes use of the WordNet Database to lookup lemmas of words.
#
# 1. Group together different infected forms of the words.
# 2. like stemming, it maps several words into one common word.
# 3. Output of limatition is a proper word.

# %%
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer

word_lem = WordNetLemmatizer()

# %%
word_lem.lemmatize('Persuation')
# Out:
# 'Persuation'

# %% [markdown]
# ## Stop Words

# %%
from nltk.corpus import stopwords

stopwords.words('english')[:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
AI_tokenize[:10]
# Out:
# ['NLTK',
#  'is',
#  'a',
#  'leading',
#  'platform',
#  'for',
#  'building',
#  'Python',
#  'programs',
#  'to']

# %%
stoopwords = stopwords.words('english')

# %%
words = [w for w in AI_tokenize if w not in stoopwords]
print(words)
# Out:
# ['NLTK', 'leading', 'platform', 'building', 'Python', 'programs', 'work', 'human', 'language', 'data', '.', 'It', 'provides', 'easy-to-use', 'interfaces', '50', 'corpora', 'lexical', 'resources', 'WordNet', ',', 'along', 'suite', 'text', 'processing', 'libraries', 'classification', ',', 'tokenization', ',', 'stemming', ',', 'tagging', ',', 'parsing', ',', 'semantic', 'reasoning', ',', 'wrappers', 'industrial-strength', 'NLP', 'libraries', ',', 'active', 'discussion', 'forum.Thanks', 'hands-on', 'guide', 'introducing', 'programming', 'fundamentals', 'alongside', 'topics', 'computational', 'linguistics', ',', 'plus', 'comprehensive', 'API', 'documentation', ',', 'NLTK', 'suitable', 'linguists', ',', 'engineers', ',', 'students', ',', 'educators', ',', 'researchers', ',', 'industry', 'users', 'alike', '.', 'NLTK', 'available', 'Windows', ',', 'Mac', 'OS', 'X', ',', 'Linux', '.', 'Best', ',', 'NLTK', 'free', ',', 'open', 'source', ',', 'community-driven', 'project', '.']

# %%
import re
punctuation = re.compile(r'[-,?!.:;(|0-9)]')

# %%
post_punctuation = []

for words in AI_tokenize:
  word = punctuation.sub("",words)
  if len(word)>0:
    post_punctuation.append(word)

post_punctuation[:10]
# Out:
# ['NLTK',
#  'is',
#  'a',
#  'leading',
#  'platform',
#  'for',
#  'building',
#  'Python',
#  'programs',
#  'to']

# %% [markdown]
# ## POS - Parts of Speech
#
# ![Screenshot (55).png](data:image/png;base64,...)

# %%
sentence1 = "The waiter cleared the plates from the table"
sentence2 = "My family persuade me to appeare for final exam"

sent1_tokenize = word_tokenize(sentence1)
sent2_tokenize = word_tokenize(sentence2)

# %%
sent1_tokenize
# Out:
# ['The', 'waiter', 'cleared', 'the', 'plates', 'from', 'the', 'table']

# %%
for token in sent1_tokenize:
  print(nltk.pos_tag([token]))
# Out:
# [('The', 'DT')]
# [('waiter', 'NN')]
# [('cleared', 'VBN')]
# [('the', 'DT')]
# [('plates', 'NNS')]
# [('from', 'IN')]
# [('the', 'DT')]
# [('table', 'NN')]

# %%
for token in sent2_tokenize:
  print(nltk.pos_tag([token]))
# Out:
# [('My', 'PRP$')]
# [('family', 'NN')]
# [('persuade', 'NN')]
# [('me', 'PRP')]
# [('to', 'TO')]
# [('appeare', 'NN')]
# [('for', 'IN')]
# [('final', 'JJ')]
# [('exam', 'NN')]

# %% [markdown]
# ## Name Entity Recognition
#
# ![Screenshot (54).png](data:image/png;base64,...)

# %%
sentence = ' Tanveer visited the Cloudy Mahabaleshwar Hills during Winter days.'

sent_tokenize = word_tokenize(sentence)
sent_tag = nltk.pos_tag(sent_tokenize)

NER = nltk.ne_chunk(sent_tag)
print(NER)
# Out:
# (S
#   (PERSON Tanveer/NNP)
#   visited/VBD
#   the/DT
#   (ORGANIZATION Cloudy/NNP Mahabaleshwar/NNP Hills/NNP)
#   during/IN
#   Winter/NNP
#   days/NNS
#   ./.)

# %% [markdown]
# ## Chunking
#
# Picking up **individual** pieces of information and **grouping** them into bigger pieces.
#
# ![Screenshot (57).png](data:image/png;base64,...)

# %%
sentence = "A big Hungry cat ate the little mouse who was after fresh cheese"
sentence_tokens = nltk.pos_tag(word_tokenize(sentence))
sentence_tokens
# Out:
# [('A', 'DT'),
#  ('big', 'JJ'),
#  ('Hungry', 'NNP'),
#  ('cat', 'NN'),
#  ('ate', 'VBD'),
#  ('the', 'DT'),
#  ('little', 'JJ'),
#  ('mouse', 'NN'),
#  ('who', 'WP'),
#  ('was', 'VBD'),
#  ('after', 'IN'),
#  ('fresh', 'JJ'),
#  ('cheese', 'NN')]

# %%
from nltk import RegexpParser

#Extract all parts of speech from any text
chunker = RegexpParser(
    '''
    NP: {}
    P: {}
    V: {}
    PP: {}
    VP: {}
    ''')

# %%
# Print all parts of speech in above sentence
output = chunker.parse(sentence_tokens)
print("After Extractingn",output)
# Out:
# After Extractingn (S
#   A/DT
#   big/JJ
#   Hungry/NNP
#   cat/NN
#   ate/VBD
#   the/DT
#   little/JJ
#   mouse/NN
#   who/WP
#   was/VBD
#   after/IN
#   fresh/JJ
#   cheese/NN)

# %%
# Require ghostscript to install
chunk_result = chunk_parser.parse(sentence_tokens)
chunk_result
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     336             method = get_real_method(obj, self.print_method)
#     337             if method is not None:
# --> 338                 return method()
#     339             return None
#     340         else:
#
# /usr/local/lib/python3.7/dist-packages/nltk/tree.py in _repr_png_(self)
#     717         from nltk.draw.util import CanvasFrame
#     718         from nltk.internals import find_binary
# --> 719         _canvas_frame = CanvasFrame()
#     720         widget = tree_to_treesegment(_canvas_frame.canvas(), self)
#     721         _canvas_frame.add_widget(widget)
#
# /usr/local/lib/python3.7/dist-packages/nltk/draw/util.py in __init__(self, parent, **kw)
#    1651         # If no parent was given, set up a top-level window.
# ...

# %% [markdown]
# Tree
#
#     ('S', [('A', 'DT'), ('big', 'JJ'), ('Hungry', 'NNP')])
#
# Tree
#
#     ('NP', [('cat', 'NN')]), ('ate', 'VBD')])
#
# Tree
#
#     ('NP', [('the', 'DT'), ('little', 'JJ'), ('mouse', 'NN')]), ('who', 'WP'), ('was', 'VBD'), ('after', 'IN')])
#
# Tree
#
#     ('NP', [('fresh', 'JJ'), ('cheese', 'NN')])
